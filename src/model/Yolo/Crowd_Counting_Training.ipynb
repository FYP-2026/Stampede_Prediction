# %%
# !pip install ultralytics roboflow -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 43.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 9.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 20.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 61.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 104.6 MB/s eta 0:00:00

# %%
from roboflow import Roboflow

API_KEY = "oTaMcMxOrulR3qqqT4R5"
WORKSPACE_ID = "onkar-dcq2w"
PROJECT_ID = "crowd-counting-dataset-w3o7w-ljwdg"
VERSION_NUMBER = 1
MODEL_FORMAT = "yolov11"

rf = Roboflow(api_key=API_KEY)
project = rf.workspace(WORKSPACE_ID).project(PROJECT_ID)
version = project.version(VERSION_NUMBER)

dataset = version.download(MODEL_FORMAT)


data_yaml_path = f"{dataset.location}/data.yaml"
print(f"Dataset downloaded to: {dataset.location}")
print(f"Path to data.yaml: {data_yaml_path}")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dataset downloaded to: /content/crowd-counting-dataset-1
# Path to data.yaml: /content/crowd-counting-dataset-1/data.yaml

# %%
# !yolo task=detect mode=train \
      model=yolo11n.pt \
      data="{data_yaml_path}" \
      epochs=50 \
      imgsz=640 \
      batch=8 \
      name='yolo11n_crowd_head_detection'
# Out:
# Ultralytics 8.3.221 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...
